# %%
l1=[1,2,34,5,677,445]
i=0
while(i<len(l1)):
    print(l1[i])
    i+=1
# Out:
# 1
# 2
# 34
# 5
# 677
# 445

# %%
ls=[2,343,64,22,66,32]

# %%
num=int(input('enter the no'))
i=0
while i<len(ls):
    if ls[i]==num:
        print(f"element at {i}")
        break
    i+=1

# %%
ls1=[1,2,4546,3,33,2]
for var in ls1:
    print(var)
# Out:
# 1
# 2
# 4546
# 3
# 33
# 2

# %%
for var in [10,20,30,40]:
    print(var**2)
# Out:
# 100
# 400
# 900
# 1600

# %%
ls1=['1','2','3','4']

# %%
ls2=[]
for var in ls1:
    ls2.append(int(ls1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 ls2=[]
#       2 for var in ls1:
# ----> 3     ls2.append(int(ls1))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %%
l1=[1,2,3,4]
l2=[10,20,30,40]

# %%
zip(l1,l2)
for i in zip(l1,l2):
    print(i)
# Out:
# (1, 10)
# (2, 20)
# (3, 30)
# (4, 40)

# %%
for i in zip(('hello','hi','bye'),['world','new','fwfn','fufkk']):
    print(i)
# Out:
# ('hello', 'world')
# ('hi', 'new')
# ('bye', 'fwfn')

# %%
ls1=['1','2','3','4']

# %%
ls2=[]
for i in ls1:
    ls2.append(int(i))

# %%
ls2
# Out:
# [1, 2, 3, 4]

# %%
for i in range(len(ls1)):
    ls1[i]=int(ls1[i])

ls1
# Out:
# [1, 2, 3, 4]

# %%
def compare(a,b):
    if a>b:
        print(f"{a}is greater thn {b}")
    else:
        print(f"{b} is greater than {a}")

compare(2,5)
# Out:
# 5 is greater than 2

# %%
ls=[1,2,3,4,5]

# %%
sum=0

for i in ls:
    sum=sum+i
print(sum)
# Out:
# 15

# %%
def addition(*var):
    sum=0
    for i in var:
        sum=sum+i
    print (sum)
addition(1,2,3,4,5,6)
# Out:
# 21
